# %%
import pandas as pd
from RNN import RNN
from GB import GB
from Trn import Transformer
from LSTM import LSTM
from SA import SA

df_load = pd.read_csv("Load.csv", index_col = 0)
df_wind = pd.read_csv("Wind.csv", index_col = 0)
df_solar = pd.read_csv("Solar.csv", index_col = 0)

# %% [markdown]
# ### Wind

# %%
RNN(df_solar)
# Out:
# /Users/lilau/Documents/Project/ECEN-360/RNN.py:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').dropna()
# Epoch 1/15 | Train Loss: 0.0897 | Val Loss: 0.1225
# Epoch 2/15 | Train Loss: 0.0758 | Val Loss: 0.1230
# Epoch 3/15 | Train Loss: 0.0814 | Val Loss: 0.1216
# Epoch 4/15 | Train Loss: 0.0795 | Val Loss: 0.1191
# Epoch 5/15 | Train Loss: 0.0749 | Val Loss: 0.1197
# Epoch 6/15 | Train Loss: 0.0730 | Val Loss: 0.1221
# Epoch 7/15 | Train Loss: 0.0735 | Val Loss: 0.1234
# Epoch 8/15 | Train Loss: 0.0743 | Val Loss: 0.1222
# Epoch 9/15 | Train Loss: 0.0735 | Val Loss: 0.1191
# Epoch 10/15 | Train Loss: 0.0717 | Val Loss: 0.1155
# Epoch 11/15 | Train Loss: 0.0697 | Val Loss: 0.1129
# Epoch 12/15 | Train Loss: 0.0685 | Val Loss: 0.1118
# Epoch 13/15 | Train Loss: 0.0683 | Val Loss: 0.1110
# Epoch 14/15 | Train Loss: 0.0678 | Val Loss: 0.1092
# ...

# %%
RNN(df_load)
# Out:
# /Users/lilau/Documents/Project/ECEN-360/RNN.py:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').dropna()
# Epoch 1/15 | Train Loss: 0.1521 | Val Loss: 0.1049
# Epoch 2/15 | Train Loss: 0.0784 | Val Loss: 0.0551
# Epoch 3/15 | Train Loss: 0.0418 | Val Loss: 0.0407
# Epoch 4/15 | Train Loss: 0.0407 | Val Loss: 0.0477
# Epoch 5/15 | Train Loss: 0.0563 | Val Loss: 0.0481
# Epoch 6/15 | Train Loss: 0.0574 | Val Loss: 0.0418
# Epoch 7/15 | Train Loss: 0.0481 | Val Loss: 0.0370
# Epoch 8/15 | Train Loss: 0.0388 | Val Loss: 0.0368
# Epoch 9/15 | Train Loss: 0.0343 | Val Loss: 0.0403
# Epoch 10/15 | Train Loss: 0.0341 | Val Loss: 0.0452
# Epoch 11/15 | Train Loss: 0.0362 | Val Loss: 0.0490
# Epoch 12/15 | Train Loss: 0.0385 | Val Loss: 0.0507
# Epoch 13/15 | Train Loss: 0.0397 | Val Loss: 0.0499
# Epoch 14/15 | Train Loss: 0.0392 | Val Loss: 0.0472
# ...

# %%
RNN(df_wind)
# Out:
# /Users/lilau/Documents/Project/ECEN-360/RNN.py:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').dropna()
# Epoch 1/15 | Train Loss: 0.3507 | Val Loss: 0.1527
# Epoch 2/15 | Train Loss: 0.2193 | Val Loss: 0.0773
# Epoch 3/15 | Train Loss: 0.1239 | Val Loss: 0.0465
# Epoch 4/15 | Train Loss: 0.0672 | Val Loss: 0.0699
# Epoch 5/15 | Train Loss: 0.0570 | Val Loss: 0.1293
# Epoch 6/15 | Train Loss: 0.0860 | Val Loss: 0.1513
# Epoch 7/15 | Train Loss: 0.0996 | Val Loss: 0.1302
# Epoch 8/15 | Train Loss: 0.0870 | Val Loss: 0.0961
# Epoch 9/15 | Train Loss: 0.0679 | Val Loss: 0.0683
# Epoch 10/15 | Train Loss: 0.0550 | Val Loss: 0.0521
# Epoch 11/15 | Train Loss: 0.0507 | Val Loss: 0.0453
# Epoch 12/15 | Train Loss: 0.0528 | Val Loss: 0.0439
# Epoch 13/15 | Train Loss: 0.0571 | Val Loss: 0.0446
# Epoch 14/15 | Train Loss: 0.0610 | Val Loss: 0.0452
# ...

# %%
GB(df_solar)
# Out:
# /Users/lilau/Documents/Project/ECEN-360/GB.py:31: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').dropna()
# Forecast Evaluation Metrics
# MSE : 3865199.3076
# MAE : 1204.7848
# R²  : 0.8325
# R   : 0.9144

# %%
GB(df_wind)
# Out:
# /Users/lilau/Documents/Project/ECEN-360/GB.py:31: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').dropna()
# Forecast Evaluation Metrics
# MSE : 21485205.4834
# MAE : 3574.2923
# R²  : 0.4029
# R   : 0.6924

# %%
GB(df_load)
# Out:
# /Users/lilau/Documents/Project/ECEN-360/GB.py:31: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').dropna()
# Forecast Evaluation Metrics
# MSE : 10942306.9347
# MAE : 2821.8414
# R²  : 0.9219
# R   : 0.9858
